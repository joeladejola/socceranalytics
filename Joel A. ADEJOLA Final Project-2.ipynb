# %%
pip install highlight-text
# Out:
# Requirement already satisfied: highlight-text in /Users/leonardo/opt/anaconda3/lib/python3.8/site-packages (0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import highlight_text

# %%
# the famous import font code to use Andale Mono
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

# %%
#Import CSV from FBref(from statbomb) from local

df = pd.read_csv('Shooting for Top 5 Leages - Sheet1.csv')

# %%
df.head()
# Out:
#    Rk                    Player Pos            Squad   90s  Gls  Sh  SoT  \
# 0   1       Max Aarons\774cf58b  DF     Norwich City  16.0    0   9    2
# 1   2        Che Adams\f2bf1b0f  FW      Southampton   9.5    3  21   11
# 2   3  Rayan Aït Nouri\9b398aea  DF           Wolves   8.0    0   6    2
# 3   4  Kristoffer Ajer\a8c0acb7  DF        Brentford   6.3    0   2    0
# 4   5       Nathan Aké\eaeca114  DF  Manchester City   4.2    0   1    0
#
#    Sh/90  SoT/90  G/Sh  G/SoT  Dist   xG  npxG  npxG/Sh  G-xG  np:G-xG
# 0   0.56    0.12  0.00   0.00  20.2  0.6   0.6     0.06  -0.6     -0.6
# 1   2.20    1.15  0.14   0.27  14.5  2.4   2.4     0.11   0.6      0.6
# 2   0.75    0.25  0.00   0.00  15.1  0.3   0.3     0.05  -0.3     -0.3
# 3   0.32    0.00  0.00    NaN   9.9  0.2   0.2     0.09  -0.2     -0.2
# 4   0.24    0.00  0.00    NaN   6.0  0.2   0.2     0.20  -0.2     -0.2

# %%
#To create npxG/90
#Which measures sum of shot qualities per 90 minutes 

df['npxG/90'] = df['npxG']/df['90s']

#To rename the table
df.rename(columns={'Dist':'Ave. Shot Distance', 'VALUE':'Tonnes of GHG'}, inplace = True)

#To drop the 'Rk' column
df.drop('Rk', axis = 1, inplace = True)

#To split player names
df['Player'] = df['Player'].str.split('\\', expand=True)[0]

# %%
#To filter out players that have not played as often
df = df[df['90s']>=6.5]

#To get rid of goalkeepers and defenders and midfielders
df = df[df['Pos']!= 'GK']
df = df[df['Pos']!= 'MF']
df = df[df['Pos']!= 'DFMF']
df = df[df['Pos']!= 'MFDF']
df = df[df['Pos']!= 'DFFW']
df = df[df['Pos']!= 'DF'].reset_index()

# %%
df.head(50)
# Out:
#     index                     Player   Pos            Squad   90s  Gls  Sh  \
# 0       1                  Che Adams    FW      Southampton   9.5    3  21
# 1      16            Michail Antonio    FW         West Ham  14.9    6  44
# 2      18             Adam Armstrong  FWMF      Southampton  12.1    2  40
# 3      21  Pierre-Emerick Aubameyang    FW          Arsenal  11.5    4  33
# 4      22                Jordan Ayew    FW   Crystal Palace  10.8    0  21
# 5      33              Harvey Barnes  FWMF   Leicester City  11.4    2  27
# 6      38              Saïd Benrahma  FWMF         West Ham  13.2    3  35
# 7      39          Christian Benteke    FW   Crystal Palace  10.7    4  35
# 8      45               Jarrod Bowen    FW         West Ham  14.6    3  39
# 9      49                Emi Buendía  MFFW      Aston Villa   9.0    1  12
# 10     80                      Cucho  FWMF          Watford   6.8    2  17
# 11     93         Leander Dendoncker  MFFW           Wolves   6.7    0   6
# 12     94            Emmanuel Dennis  FWMF          Watford  13.0    7  32
# 13     97       Raphael Dias Belloli  MFFW     Leeds United  13.0    7  42
# 14    114            Odsonne Édouard    FW   Crystal Palace   7.8    3  18
# 15    133                 Phil Foden    FW  Manchester City   8.0    3  20
# 16    134              Pablo Fornals  FWMF         West Ham  13.6    4  22
# 17    158               Demarai Gray  MFFW          Everton  13.7    5  35
# 18    159              Jack Grealish  FWMF  Manchester City   9.8    1  24
# 19    160            Mason Greenwood    FW   Manchester Utd   9.4    4  32
# 20    166              Jack Harrison  MFFW     Leeds United  10.9    0  12
# 21    168                Kai Havertz  FWMF          Chelsea   9.5    2  26
# 22    170             Hwang Hee-chan  FWMF           Wolves  10.7    4  10
# 23    174              Son Heung-min  FWMF        Tottenham  12.6    6  31
# 24    178         Callum Hudson-Odoi  FWMF          Chelsea   6.6    1  10
# 25    183                 Danny Ings    FW      Aston Villa   9.3    3  12
# 26    186               Daniel James  FWMF     Leeds United  11.2    1  26
# 27    191              Gabriel Jesus    FW  Manchester City  11.6    2  33
# 28    192               Raúl Jiménez    FW           Wolves  14.5    3  31
# 29    193                  Joelinton  MFFW    Newcastle Utd  10.5    1  19
# 30    197                 Diogo Jota    FW        Liverpool  11.5    8  39
# 31    201                 Harry Kane    FW        Tottenham  12.2    1  32
# 32    209                Joshua King    FW          Watford  12.1    5  27
# 33    240            Ademola Lookman  FWMF   Leicester City   6.5    1  10
# 34    244              Romelu Lukaku    FW          Chelsea   7.7    3  19
# 35    247             James Maddison  MFFW   Leicester City  11.2    4  29
# 36    251                 Sadio Mané    FW        Liverpool  15.1    7  51
# 37    264                Neal Maupay    FW         Brighton  11.3    6  26
# 38    265               Bryan Mbeumo    FW        Brentford  14.2    3  35
# 39    285                Jakub Moder  MFFW         Brighton   8.7    0  15
# 40    288                Mason Mount  MFFW          Chelsea   8.9    6  22
# 41    289                Lucas Moura  FWMF        Tottenham  11.0    1  20
# 42    327                 Paul Pogba  MFFW   Manchester Utd   7.0    0  20
# 43    329                Teemu Pukki    FW     Norwich City  15.2    5  29
# 44    334               Jacob Ramsey  MFFW      Aston Villa   9.1    1  13
# 45    336              Milot Rashica  FWMF     Norwich City   9.0    0  18
# 46    338             Nathan Redmond  MFFW      Southampton  10.6    0  17
# 47    342                Richarlison  FWMF          Everton   9.8    3  18
# 48    346              Tyler Roberts  FWMF     Leeds United   6.9    1  19
# 49    350                    Rodrigo  MFFW     Leeds United  10.0    2  22
#
#     SoT  Sh/90  SoT/90  G/Sh  G/SoT  Ave. Shot Distance   xG  npxG  npxG/Sh  \
# 0    11   2.20    1.15  0.14   0.27                14.5  2.4   2.4     0.11
# 1    12   2.94    0.80  0.14   0.50                15.2  5.4   5.2     0.12
# 2    13   3.31    1.07  0.05   0.15                17.6  3.8   3.8     0.10
# 3    16   2.86    1.39  0.12   0.25                14.2  5.8   4.1     0.13
# 4     3   1.94    0.28  0.00   0.00                17.6  1.9   1.9     0.09
# 5    12   2.37    1.05  0.07   0.17                15.8  2.3   2.3     0.09
# 6    12   2.65    0.91  0.09   0.25                20.0  2.3   2.3     0.06
# 7    11   3.26    1.03  0.11   0.36                11.4  5.0   5.0     0.14
# 8    15   2.67    1.03  0.08   0.20                16.7  4.8   4.8     0.12
# 9     3   1.33    0.33  0.08   0.33                17.3  1.1   1.1     0.09
# 10    4   2.51    0.59  0.12   0.50                18.4  0.9   0.9     0.05
# 11    2   0.89    0.30  0.00   0.00                20.3  0.4   0.4     0.07
# 12   17   2.47    1.31  0.22   0.41                14.7  3.9   3.9     0.12
# 13   13   3.24    1.00  0.12   0.38                21.6  4.7   3.2     0.08
# 14    8   2.32    1.03  0.17   0.38                14.4  2.2   2.2     0.12
# 15   11   2.50    1.37  0.15   0.27                12.6  4.1   4.1     0.21
# 16    8   1.61    0.59  0.18   0.50                17.8  2.9   2.9     0.13
# 17   10   2.55    0.73  0.14   0.50                20.7  2.5   2.5     0.07
# 18   10   2.45    1.02  0.04   0.10                14.5  3.2   3.2     0.13
# 19   12   3.40    1.27  0.13   0.33                18.8  2.6   2.6     0.08
# 20    3   1.10    0.27  0.00   0.00                17.0  0.9   0.9     0.07
# 21    8   2.73    0.84  0.08   0.25                14.4  2.9   2.9     0.11
# 22    5   0.93    0.47  0.40   0.80                13.0  2.2   2.2     0.22
# 23   13   2.45    1.03  0.19   0.46                17.5  4.3   4.3     0.14
# 24    6   1.51    0.91  0.10   0.17                13.7  1.2   1.2     0.12
# 25    5   1.29    0.54  0.17   0.40                13.6  2.2   1.5     0.12
# 26    4   2.32    0.36  0.04   0.25                17.4  1.9   1.9     0.07
# 27   11   2.83    0.94  0.06   0.18                13.6  4.3   4.3     0.13
# 28    7   2.14    0.48  0.10   0.43                14.9  3.3   3.3     0.11
# 29    7   1.81    0.67  0.05   0.14                17.1  1.3   1.3     0.07
# 30   14   3.39    1.22  0.21   0.57                10.9  8.9   8.9     0.23
# 31   14   2.62    1.15  0.03   0.07                18.0  3.8   3.8     0.12
# 32   11   2.24    0.91  0.15   0.36                13.7  5.8   5.0     0.19
# 33    4   1.54    0.61  0.10   0.25                14.0  2.0   2.0     0.20
# 34    5   2.46    0.65  0.16   0.60                12.6  3.2   3.2     0.17
# 35   13   2.60    1.17  0.14   0.31                19.8  3.2   3.2     0.11
# 36   17   3.37    1.12  0.14   0.41                12.7  8.3   8.3     0.16
# 37    8   2.30    0.71  0.19   0.63                15.2  4.8   4.1     0.16
# 38    6   2.47    0.42  0.06   0.33                17.7  5.4   4.7     0.13
# 39    2   1.72    0.23  0.00   0.00                16.3  1.4   1.4     0.10
# 40   12   2.48    1.35  0.23   0.42                18.5  4.0   3.2     0.15
# 41    5   1.82    0.45  0.05   0.20                17.7  1.5   1.5     0.08
# 42    3   2.85    0.43  0.00   0.00                17.0  1.6   1.6     0.08
# 43   10   1.91    0.66  0.10   0.30                14.2  4.9   3.4     0.12
# 44    2   1.43    0.22  0.08   0.50                19.4  1.0   1.0     0.08
# 45    7   2.01    0.78  0.00   0.00                22.3  1.1   1.1     0.06
# 46    3   1.61    0.28  0.00   0.00                19.0  1.7   1.7     0.10
# 47    4   1.83    0.41  0.17   0.75                15.3  2.4   2.4     0.13
# 48    9   2.74    1.30  0.05   0.11                17.0  1.8   1.8     0.10
# 49    8   2.21    0.80  0.05   0.13                19.4  2.7   1.9     0.09
#
#     G-xG  np:G-xG   npxG/90
# 0    0.6      0.6  0.252632
# 1    0.6      0.8  0.348993
# 2   -1.8     -1.8  0.314050
# 3   -1.8     -0.1  0.356522
# 4   -1.9     -1.9  0.175926
# 5   -0.3     -0.3  0.201754
# 6    0.7      0.7  0.174242
# 7   -1.0     -1.0  0.467290
# 8   -1.8     -1.8  0.328767
# 9   -0.1     -0.1  0.122222
# 10   1.1      1.1  0.132353
# 11  -0.4     -0.4  0.059701
# 12   3.1      3.1  0.300000
# 13   2.3      1.8  0.246154
# 14   0.8      0.8  0.282051
# 15  -1.1     -1.1  0.512500
# 16   1.1      1.1  0.213235
# 17   2.5      2.5  0.182482
# 18  -2.2     -2.2  0.326531
# 19   1.4      1.4  0.276596
# 20  -0.9     -0.9  0.082569
# 21  -0.9     -0.9  0.305263
# 22   1.8      1.8  0.205607
# 23   1.7      1.7  0.341270
# 24  -0.2     -0.2  0.181818
# 25   0.8      0.5  0.161290
# 26  -0.9     -0.9  0.169643
# 27  -2.3     -2.3  0.370690
# 28  -0.3     -0.3  0.227586
# 29  -0.3     -0.3  0.123810
# 30  -0.9     -0.9  0.773913
# 31  -2.8     -2.8  0.311475
# 32  -0.8     -1.0  0.413223
# 33  -1.0     -1.0  0.307692
# 34  -0.2     -0.2  0.415584
# 35   0.8      0.8  0.285714
# 36  -1.3     -1.3  0.549669
# 37   1.2      0.9  0.362832
# 38  -2.4     -2.7  0.330986
# 39  -1.4     -1.4  0.160920
# 40   2.0      1.8  0.359551
# 41  -0.5     -0.5  0.136364
# 42  -1.6     -1.6  0.228571
# 43   0.1     -0.4  0.223684
# 44   0.0      0.0  0.109890
# 45  -1.1     -1.1  0.122222
# 46  -1.7     -1.7  0.160377
# 47   0.6      0.6  0.244898
# 48  -0.8     -0.8  0.260870
# 49  -0.7     -0.9  0.190000

# %%
#To set color for background and color of text
background = '#313332'
text_color = 'white'

#To set the background and axis ticks to the colors above
fig, ax = plt.subplots(figsize=(10,5))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

#To get rid of axis lines
spines = ['top', 'bottom', 'left', 'right']
for x in spines:
    if x in spines:
        ax.spines[x].set_visible(False)
        
sns.swarmplot(x='npxG/90', data = df, color = 'white',zorder=1)


#Plot Grealish
plt.scatter(0.326531,y=0,c='red',s=100,zorder=2)

# %%
#To create list of metrics we are using
metrics = ['npxG/90', 'xG', 'Gls', 'npxG/Sh', 'Ave. Shot Distance', 'np:G-xG']

# %%
#Layout for the grid
fig,axes = plt.subplots(3,2,figsize=(20,10))
fig.set_facecolor(background)
ax.patch.set_facecolor(background)

#set up our base layer
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = text_color

#create a list of comparisons
counter=0
counter2=0
met_counter = 0

#Set up for-loop to plot layout of the metrics one by one
for i,ax in zip(df['Player'],axes.flatten()):
    ax.set_facecolor(background)
    ax.grid(ls='dotted',lw=.5,color='lightgrey',axis='y',zorder=1)
    
#To remove the spines of each plot again
    spines = ['top','bottom','left','right']
    for x in spines:
        if x in spines:
            ax.spines[x].set_visible(False)
            
#For loop to begin the plots for the first metric then end it after it completes the len of metrics          
    sns.swarmplot(x=metrics[met_counter],data=df,ax=axes[counter,counter2],zorder=1,color='white')
    ax.set_xlabel(f'{metrics[met_counter]}',c=text_color)
    
    for x in range(len(df['Player'])):
        if df['Player'][x] == 'Mohamed Salah':
            ax.scatter(x=df[metrics[met_counter]][x],y=0,s=200,c='red',zorder=2)
                        
    met_counter+=1
    if counter2 == 0:
        counter2 = 1
        continue
    if counter2 == 1:
        counter2 = 0
        counter+=1

s='<Mohamed Salah> La Liga Attacking Stats (2021/2022 Season)'
highlight_text.fig_text(s=s,
                x=.25, y=.88,
                #highlight_weights = ['bold'],
                fontsize=22,
                fontfamily = 'Andale Mono',
                color = text_color,
                #highlight_colours = ['#6CABDD'],
                va='center'
               )

fig.text(.12,.05,"Plot includes Forwards from Europe's Top 5 Leagues/ Goal Keepers, Defender, Midfielders and those with less than 6.5 90's played excluded",fontsize=11, fontfamily='Andale Mono',color=text_color)
fig.text(.12,.03,"@joeladejola / data via fbref.com + Statsbomb", fontstyle='italic',fontsize=11, fontfamily='Andale Mono',color=text_color)
fig.text(.12,.01,"inspired by @mckayjohns", fontstyle='italic',fontsize=11, fontfamily='Andale Mono',color=text_color)


plt.savefig('test.png',dpi=500,bbox_inches = 'tight',facecolor=background)
# Out:
# /Users/leonardo/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 40.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/leonardo/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 9.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
print(df.head())

df.Player.unique()
# Out:
#    index                     Player   Pos           Squad   90s  Gls  Sh  SoT  \
# 0      1                  Che Adams    FW     Southampton   9.5    3  21   11
# 1     16            Michail Antonio    FW        West Ham  14.9    6  44   12
# 2     18             Adam Armstrong  FWMF     Southampton  12.1    2  40   13
# 3     21  Pierre-Emerick Aubameyang    FW         Arsenal  11.5    4  33   16
# 4     22                Jordan Ayew    FW  Crystal Palace  10.8    0  21    3
#
#    Sh/90  SoT/90  G/Sh  G/SoT  Ave. Shot Distance   xG  npxG  npxG/Sh  G-xG  \
# 0   2.20    1.15  0.14   0.27                14.5  2.4   2.4     0.11   0.6
# 1   2.94    0.80  0.14   0.50                15.2  5.4   5.2     0.12   0.6
# 2   3.31    1.07  0.05   0.15                17.6  3.8   3.8     0.10  -1.8
# 3   2.86    1.39  0.12   0.25                14.2  5.8   4.1     0.13  -1.8
# 4   1.94    0.28  0.00   0.00                17.6  1.9   1.9     0.09  -1.9
#
#    np:G-xG   npxG/90
# 0      0.6  0.252632
# 1      0.8  0.348993
# 2     -1.8  0.314050
# 3     -0.1  0.356522
# 4     -1.9  0.175926
# array(['Che Adams', 'Michail Antonio', 'Adam Armstrong',
#        'Pierre-Emerick Aubameyang', 'Jordan Ayew', 'Harvey Barnes',
#        'Saïd Benrahma', 'Christian Benteke', 'Jarrod Bowen',
#        'Emi Buendía', 'Cucho', 'Leander Dendoncker', 'Emmanuel Dennis',
#        'Raphael Dias Belloli', 'Odsonne Édouard', 'Phil Foden',
#        'Pablo Fornals', 'Demarai Gray', 'Jack Grealish',
#        'Mason Greenwood', 'Jack Harrison', 'Kai Havertz',
#        'Hwang Hee-chan', 'Son Heung-min', 'Callum Hudson-Odoi',
#        'Danny Ings', 'Daniel James', 'Gabriel Jesus', 'Raúl Jiménez',
#        'Joelinton', 'Diogo Jota', 'Harry Kane', 'Joshua King',
#        'Ademola Lookman', 'Romelu Lukaku', 'James Maddison', 'Sadio Mané',
#        'Neal Maupay', 'Bryan Mbeumo', 'Jakub Moder', 'Mason Mount',
#        'Lucas Moura', 'Paul Pogba', 'Teemu Pukki', 'Jacob Ramsey',
#        'Milot Rashica', 'Nathan Redmond', 'Richarlison', 'Tyler Roberts',
#        'Rodrigo', 'Cristiano Ronaldo', 'Salomón Rondón',
#        'Allan Saint-Maximin', 'Bukayo Saka', 'Mohamed Salah',
#        'Jadon Sancho', 'Josh Sargent', 'Ismaila Sarr', 'Emile Smith-Rowe',
#        'Raheem Sterling', 'Ivan Toney', 'Adama Traoré',
#        'Francisco Trincão', 'Leandro Trossard', 'Jamie Vardy',
#        'Ollie Watkins', 'Callum Wilson', 'Chris Wood', 'Wilfried Zaha',
#        'Yacine Adli', 'Ludovic Ajorque', 'Mohamed Ali Cho',
#        'Jim Allevinah', 'Houssem Aouar', 'Mohamed Bayo',
#        'Wissam Ben Yedder', 'El Bilal Touré', 'Ludovic Blas',
#        'Myron Boadu', 'Denis Bouanga', 'Ryad Boudebouz', 'Sofiane Boufal',
#        'Farid Boulaya', 'Benjamin Bourigeaud', 'Irvin Cardona',
#        'Jonathan David', 'Andy Delort', 'Moussa Dembélé',
#        'Ángel Di María', 'Habib Diallo', 'Javairô Dilrosun',
#        'Sofiane Diop', 'Kasper Dolberg', 'Jodel Dossou', 'Hugo Ekitike',
#        'Alberth Elis', 'Sepe Elye Wahi', 'Alexis Flips', 'Angelo Fulgini',
#        'Kévin Gameiro', 'Ignatius Ganago', 'Valère Germain',
#        'Aleksandr Golovin', 'Amine Gouiri', 'Romain Hamouma',
#        'Franck Honorat', 'Mauro Icardi', 'Jonathan Ikone', 'Gaël Kakuta',
#        'Arnaud Kalimuendo', 'Ilan Kebbal', 'Wahbi Khazri',
#        'Randal Kolo Muani', 'Gaëtan Laborde', 'Armand Lauriente',
#        'Jérémy Le Douaron', 'Gelson Martins', 'Stephy Mavididi',
#        'Kylian Mbappé', 'Nathanael Mbuku', 'Lionel Messi', 'Terem Moffi',
#        'Florent Mollet', 'Steve Mounié', 'Neymar', 'Ibrahima Niane',
#        'Arnaud Nordin', 'Remi Oudin', 'Lucas Paquetá', 'Dimitri Payet',
#        'Nicolas de Préville', 'Elba Rashani', 'Renaud Ripart',
#        'Mama Samba Baldé', 'Renato Sanches', 'Moses Simon',
#        'Florian Sotoca', 'Kamaldeen Sulemana', 'Martin Terrier',
#        'Karl Toko Ekambi', 'Yoann Touzghar', 'Hwang Ui-jo',
#        'Cengiz Ünder', 'Kevin Volland', 'Timothy Weah', 'Burak Yılmaz',
#        'Amine Adli', 'Sebastian Andersson', 'Takuma Asano',
#        'Taiwo Awoniyi', 'Ridle Baku', 'Christoph Baumgartner',
#        'Ihlas Bebou', 'Rafael Borré', 'Julian Brandt',
#        'Jonathan Burkardt', 'Moussa Diaby', 'Breel Embolo',
#        'Emil Forsberg', 'Philipp Förster', 'Serge Gnabry',
#        'Vincenzo Grifo', 'Erling Haaland', 'Robin Hack', 'André Hahn',
#        'Jonas Hofmann', 'Lucas Höler', 'Gerrit Holtmann',
#        'Branimir Hrgota', 'Cedric Itten', 'Lee Jae-sung', 'Florian Kainz',
#        'Daichi Kamada', 'Fabian Klos', 'Andrej Kramarić', 'Max Kruse',
#        'Robert Lewandowski', 'Jamie Leweling', 'Jesper Lindstrøm',
#        'Dejan Ljubicic', 'Dodi Lukebakio', 'Donyell Malen',
#        'Omar Marmoush', 'Maximilian Mittelstädt', 'Anthony Modeste',
#        'Håvard Nielsen', 'Christopher Nkunku', 'Lukas Nmecha',
#        'Masaya Okugawa', 'Karim Onisiwo', 'Maximilian Philipp',
#        'Alassane Pléa', 'Sebastian Polter', 'Marco Reus', 'Marco Richter',
#        'Georginio Rutter', 'Leroy Sané', 'Patrik Schick', 'Suat Serdar',
#        'André Silva', 'Lars Stindl', 'Dominik Szoboszlai', 'Mark Uth',
#        'Ruben Vargas', 'Wout Weghorst', 'Patrick Wimmer', 'Florian Wirtz',
#        'Jeong Woo-yeong', 'Andi Zeqiri', 'Tammy Abraham',
#        'Felipe Anderson', 'Janis Antiste', 'Mattia Aramu',
#        'Marko Arnautović', 'Nedim Bajrami', 'Keita Baldé',
#        'Antonín Barák', 'Musa Barrow', 'Domenico Berardi',
#        'Federico Bernardeschi', 'Beto', 'Jeremie Boga',
#        'Federico Bonazzoli', 'Josip Brekalo', 'José Callejón',
#        'Antonio Candreva', 'Gianluca Caprari', 'Francesco Caputo',
#        'Federico Chiesa', 'Mamadou Coulibaly', 'Patrick Cutrone',
#        'Mattia Destro', 'Gerard Deulofeu', 'Federico Di Francesco',
#        'Paulo Dybala', 'Edin Džeko', 'Caleb Ekuban', 'Elif Elmas',
#        'Manolo Gabbiadini', 'Nicolás González', 'Emmanuel Gyasi',
#        'Thomas Henry', 'Zlatan Ibrahimović', 'Josip Iličić',
#        'Ciro Immobile', 'Lorenzo Insigne', 'Dennis Johnsen',
#        'Hamed Junior Traorè', 'Yayah Kallon', 'Sofian Kiyine',
#        'Rade Krunić', 'Dejan Kulusevski', 'Rafael Leão', 'Karol Linetty',
#        'Hirving Lozano', 'Ruslan Malinovskyi', 'Lautaro Martínez',
#        'Henrikh Mkhitaryan', 'Álvaro Morata', 'Simeon Nwankwo',
#        "M'Bala Nzola", 'Joel Obi', 'David Okereke', 'Riccardo Orsolini',
#        'Victor Osimhen', 'Goran Pandev', 'Mario Pašalić', 'Pedro',
#        'João Pedro', 'Roberto Pereyra', 'Matteo Pessina',
#        'Andrea Pinamonti', 'Matteo Politano', 'Dennis Praet',
#        'Ignacio Pussetto', 'Fabio Quagliarella', 'Giacomo Raspadori',
#        'Franck Ribéry', 'Alexis Saelemaekers', 'Antonio Sanabria',
#        'Riccardo Saponara', 'Gianluca Scamacca', 'Giovanni Simeone',
#        'Roberto Soriano', 'Riccardo Sottil', 'Daniele Verde',
#        'Dušan Vlahović', 'Nicolò Zaniolo', 'Duván Zapata', 'Milan Đurić',
#        'Filip Đuričić', 'Carles Aleñá', 'Marco Asensio', 'Iago Aspas',
#        'Ezequiel Ávila', 'Darío Benedetto', 'Karim Benzema', 'Lucas Boyé',
#        'Sergio Canales', 'Ángel Correa', 'Hélder Costa', 'Memphis Depay',
#        'Boulaye Dia', 'Hugo Duro', 'Adri Embarba', 'Jorge de Frutos',
#        'Álvaro García', 'Raúl García', 'Rubén García', 'Maxi Gómez',
#        'Papu Gómez', 'Antoine Griezmann', 'Arnaut Groeneveld',
#        'Gonçalo Guedes', 'Alexander Isak', 'Adnan Januzaj',
#        'Luis Javier Suárez', 'Willian José', 'Joselu', 'Juanmi',
#        'Vinicius Júnior', 'Lee Kangin', 'Kike', 'Érik Lamela',
#        'Anthony Lozano', 'José Luis Morales', 'Roger Martí',
#        'Brais Méndez', 'Santi Mina', 'Rafa Mir', 'Jorge Molina',
#        'Álvaro Negredo', 'Randy Ntekja', 'Lucas Ocampos',
#        'Mikel Oyarzabal', 'Gavi Paez', 'Isaac Palazón Camacho',
#        'Lucas Pérez', 'Yeremi Pino', 'Portu', 'Javi Puado',
#        'Antonio Puertas', 'Sandro Ramírez', 'Nico Ribaudo', 'Luis Rioja',
#        'Rubén Rochina', 'Ángel Rodríguez', 'Dani Rodríguez', 'Salvi',
#        'Oihan Sancet', 'Rubén Sobrino', 'Luis Suárez', 'Raúl de Tomás',
#        'Manu Trigueros', 'Enes Ünal', 'Iñaki Williams'], dtype=object)
